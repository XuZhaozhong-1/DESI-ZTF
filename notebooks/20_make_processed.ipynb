# %% [markdown]
# # 20 — Make Processed (inspect interim, split bins)

# %%
from pathlib import Path
import pandas as pd
import numpy as np

INTER = Path.home()/ 'project/data/interim'
PROC  = Path.home()/ 'project/data/processed'

# Load your interim FITS/parquet
# Example if you copied new_d_y3.fits:
# import fitsio
# with fitsio.FITS(INTER/'new_d_y3.fits') as f:
#     df = pd.DataFrame(f[1].read())

# or parquet
# df = pd.read_parquet(INTER/'y3_qso_clean.parquet')

# TODO: quick histograms, z-cuts preview, save per-bin parquet if needed
