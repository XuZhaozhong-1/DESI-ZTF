# %% [markdown]
# # 30 — MCMC diagnostics (trace, ESS, R-hat, corner)

# %%
from pathlib import Path
import numpy as np
# Optional: import arviz as az
PER = Path.home()/ 'project/results/mcmc/per_bin'

# Example load one chain
# d = np.load(PER/'y3_bin1_z2.3-2.4.npz', allow_pickle=True)
# print(list(d.keys()))
# TODO: trace/corner/ESS
