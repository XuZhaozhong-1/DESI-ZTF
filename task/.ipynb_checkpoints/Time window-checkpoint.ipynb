# %%
import pandas as pd
import h5py
import matplotlib.pyplot as plt
import numpy as np
from astropy.cosmology import Planck18
import matplotlib.pyplot as plt

# %% [markdown]
# # Load data from dates.hdf5 and use only targetid’s with zwarn=0

# %%
f = h5py.File('./dates.hdf5')
for name in f['df']:
    print(name)
print('//////////')
for name in f['df']['block0_items']:
    print(name)
print('//////////')
for name in f['df']['block1_items']:
    print(name)
print('//////////')
# Out:
# axis0
# axis1
# block0_items
# block0_values
# block1_items
# block1_values
# //////////
# b'mjd'
# b'z'
# b'zerr'
# b'zwarn'
# //////////
# b'targetid'
# b'night'
# //////////

# %%
mjd = np.array(f['df']['block0_values'][:,0])
z = np.array(f['df']['block0_values'][:,1])
zerr = np.array(f['df']['block0_values'][:,2])
zwarn = np.array(f['df']['block0_values'][:,3])
targetid = np.array(f['df']['block1_values'][:,0])
night = np.array(f['df']['block1_values'][:,1])

# %%
#Use only targetid’s with zwarn=0
index = (zwarn == 0)
mjd_sld = mjd[index]
z_sld = z[index]
zerr_sld = zerr[index]
zwarn_sld = zwarn[index]
targetid_sld = targetid[index]
night_sld = night[index]
d = Planck18.distmod(z_sld)

# %% [markdown]
# # Load data from lc foler and and reject datas that have a problem

# %% [markdown]
# # Each Band is independent of others

# %%
from tqdm import tqdm
import h5py

# Define lists as comprehensions
target_id_g = []
mag_g = []
magerr_g = []
target_id_r = []
mag_r = []
magerr_r = []
target_id_i = []
mag_i = []
magerr_i = []

for x in tqdm(range(377, 1897)):
    file_path = f"lc/{x:06d}.hdf5"
    try:
        with h5py.File(file_path, 'r') as file:
            keys = list(file.keys())
            for key in keys:
                if 'g' in file[key]:
                    g_data = file[key]['g']
                    if 'mag' in g_data and 'magerr' in g_data:
                        indices = (g_data['catflags'][:] & 32768) == 0
                        target_id_g.append(key)
                        mag_g.append(g_data['mag'][indices])
                        magerr_g.append(g_data['magerr'][indices])
                if 'r' in file[key]:
                    r_data = file[key]['r']
                    if 'mag' in r_data and 'magerr' in r_data:
                        indices = (r_data['catflags'][:] & 32768) == 0
                        target_id_r.append(key)
                        mag_r.append(r_data['mag'][indices])
                        magerr_r.append(r_data['magerr'][indices])
                if 'i' in file[key]:
                    i_data = file[key]['i']
                    if 'mag' in i_data and 'magerr' in i_data:
                        indices = (i_data['catflags'][:] & 32768) == 0
                        target_id_i.append(key)
                        mag_i.append(i_data['mag'][indices])
                        magerr_i.append(i_data['magerr'][indices])
    except FileNotFoundError as e:
        print(f"File not found: {file_path}. Skipping it.")
    except Exception as e:
        print(f"Error processing file: {file_path}. Skipping it.")
# Out:
#  52%|█████▏    | 791/1520 [34:36<00:12, 57.88it/s]
# File not found: lc/000878.hdf5. Skipping it.
# File not found: lc/000879.hdf5. Skipping it.
# File not found: lc/000882.hdf5. Skipping it.
# File not found: lc/000883.hdf5. Skipping it.
# File not found: lc/000884.hdf5. Skipping it.
# File not found: lc/000885.hdf5. Skipping it.
# File not found: lc/000886.hdf5. Skipping it.
# File not found: lc/000887.hdf5. Skipping it.
# File not found: lc/000888.hdf5. Skipping it.
# File not found: lc/000889.hdf5. Skipping it.
# File not found: lc/000890.hdf5. Skipping it.
# File not found: lc/000891.hdf5. Skipping it.
# File not found: lc/000892.hdf5. Skipping it.
# File not found: lc/000893.hdf5. Skipping it.
# File not found: lc/000894.hdf5. Skipping it.
# File not found: lc/000895.hdf5. Skipping it.
# File not found: lc/000896.hdf5. Skipping it.
# File not found: lc/000897.hdf5. Skipping it.
# File not found: lc/000898.hdf5. Skipping it.
# File not found: lc/000899.hdf5. Skipping it.
# File not found: lc/000900.hdf5. Skipping it.
# File not found: lc/000901.hdf5. Skipping it.
# File not found: lc/000902.hdf5. Skipping it.
# File not found: lc/000903.hdf5. Skipping it.
# File not found: lc/000904.hdf5. Skipping it.
# File not found: lc/000905.hdf5. Skipping it.
# File not found: lc/000906.hdf5. Skipping it.
# File not found: lc/000907.hdf5. Skipping it.
# File not found: lc/000908.hdf5. Skipping it.
# File not found: lc/000909.hdf5. Skipping it.
# File not found: lc/000910.hdf5. Skipping it.
# File not found: lc/000911.hdf5. Skipping it.
# File not found: lc/000912.hdf5. Skipping it.
# File not found: lc/000913.hdf5. Skipping it.
# File not found: lc/000914.hdf5. Skipping it.
# File not found: lc/000915.hdf5. Skipping it.
# File not found: lc/000916.hdf5. Skipping it.
# File not found: lc/000917.hdf5. Skipping it.
# File not found: lc/000918.hdf5. Skipping it.
# File not found: lc/000919.hdf5. Skipping it.
# File not found: lc/000920.hdf5. Skipping it.
# File not found: lc/000921.hdf5. Skipping it.
# File not found: lc/000922.hdf5. Skipping it.
# File not found: lc/000923.hdf5. Skipping it.
# File not found: lc/000924.hdf5. Skipping it.
# File not found: lc/000925.hdf5. Skipping it.
# File not found: lc/000926.hdf5. Skipping it.
# File not found: lc/000927.hdf5. Skipping it.
# File not found: lc/000928.hdf5. Skipping it.
# File not found: lc/000929.hdf5. Skipping it.
# File not found: lc/000930.hdf5. Skipping it.
# File not found: lc/000931.hdf5. Skipping it.
# File not found: lc/000932.hdf5. Skipping it.
# File not found: lc/000933.hdf5. Skipping it.
# File not found: lc/000934.hdf5. Skipping it.
# File not found: lc/000935.hdf5. Skipping it.
# File not found: lc/000936.hdf5. Skipping it.
# File not found: lc/000937.hdf5. Skipping it.
# File not found: lc/000938.hdf5. Skipping it.
# File not found: lc/000939.hdf5. Skipping it.
# File not found: lc/000940.hdf5. Skipping it.
# File not found: lc/000941.hdf5. Skipping it.
# File not found: lc/000942.hdf5. Skipping it.
# File not found: lc/000943.hdf5. Skipping it.
# File not found: lc/000944.hdf5. Skipping it.
# File not found: lc/000945.hdf5. Skipping it.
# File not found: lc/000946.hdf5. Skipping it.
# File not found: lc/000947.hdf5. Skipping it.
# File not found: lc/000948.hdf5. Skipping it.
# File not found: lc/000949.hdf5. Skipping it.
# File not found: lc/000950.hdf5. Skipping it.
# File not found: lc/000951.hdf5. Skipping it.
# File not found: lc/000952.hdf5. Skipping it.
# File not found: lc/000953.hdf5. Skipping it.
# File not found: lc/000954.hdf5. Skipping it.
# File not found: lc/000955.hdf5. Skipping it.
# File not found: lc/000956.hdf5. Skipping it.
# File not found: lc/000957.hdf5. Skipping it.
# File not found: lc/000958.hdf5. Skipping it.
# File not found: lc/000959.hdf5. Skipping it.
# File not found: lc/000960.hdf5. Skipping it.
# File not found: lc/000961.hdf5. Skipping it.
# File not found: lc/000962.hdf5. Skipping it.
# File not found: lc/000963.hdf5. Skipping it.
# File not found: lc/000964.hdf5. Skipping it.
# File not found: lc/000965.hdf5. Skipping it.
# File not found: lc/000966.hdf5. Skipping it.
# File not found: lc/000967.hdf5. Skipping it.
# File not found: lc/000968.hdf5. Skipping it.
# File not found: lc/000969.hdf5. Skipping it.
# File not found: lc/000970.hdf5. Skipping it.
# File not found: lc/000971.hdf5. Skipping it.
# File not found: lc/000972.hdf5. Skipping it.
# File not found: lc/000973.hdf5. Skipping it.
# File not found: lc/000974.hdf5. Skipping it.
# File not found: lc/000975.hdf5. Skipping it.
# File not found: lc/000976.hdf5. Skipping it.
# File not found: lc/000977.hdf5. Skipping it.
# File not found: lc/000978.hdf5. Skipping it.
# File not found: lc/000979.hdf5. Skipping it.
# File not found: lc/000980.hdf5. Skipping it.
# File not found: lc/000981.hdf5. Skipping it.
# File not found: lc/000982.hdf5. Skipping it.
# File not found: lc/000983.hdf5. Skipping it.
# File not found: lc/000984.hdf5. Skipping it.
# File not found: lc/000985.hdf5. Skipping it.
# File not found: lc/000986.hdf5. Skipping it.
# File not found: lc/000987.hdf5. Skipping it.
# File not found: lc/000988.hdf5. Skipping it.
# File not found: lc/000989.hdf5. Skipping it.
# File not found: lc/000990.hdf5. Skipping it.
# File not found: lc/000991.hdf5. Skipping it.
# File not found: lc/000992.hdf5. Skipping it.
# File not found: lc/000993.hdf5. Skipping it.
# File not found: lc/000994.hdf5. Skipping it.
# File not found: lc/000995.hdf5. Skipping it.
# File not found: lc/000996.hdf5. Skipping it.
# File not found: lc/000997.hdf5. Skipping it.
# File not found: lc/000998.hdf5. Skipping it.
# File not found: lc/000999.hdf5. Skipping it.
# File not found: lc/001000.hdf5. Skipping it.
# File not found: lc/001001.hdf5. Skipping it.
# File not found: lc/001002.hdf5. Skipping it.
# File not found: lc/001003.hdf5. Skipping it.
# File not found: lc/001004.hdf5. Skipping it.
# File not found: lc/001005.hdf5. Skipping it.
# File not found: lc/001006.hdf5. Skipping it.
# File not found: lc/001007.hdf5. Skipping it.
# File not found: lc/001008.hdf5. Skipping it.
# File not found: lc/001009.hdf5. Skipping it.
# File not found: lc/001010.hdf5. Skipping it.
# File not found: lc/001011.hdf5. Skipping it.
# File not found: lc/001012.hdf5. Skipping it.
# File not found: lc/001013.hdf5. Skipping it.
# File not found: lc/001014.hdf5. Skipping it.
# File not found: lc/001015.hdf5. Skipping it.
# File not found: lc/001016.hdf5. Skipping it.
# File not found: lc/001017.hdf5. Skipping it.
# File not found: lc/001018.hdf5. Skipping it.
# File not found: lc/001019.hdf5. Skipping it.
# File not found: lc/001020.hdf5. Skipping it.
# File not found: lc/001021.hdf5. Skipping it.
# File not found: lc/001022.hdf5. Skipping it.
# File not found: lc/001023.hdf5. Skipping it.
# File not found: lc/001024.hdf5. Skipping it.
# File not found: lc/001025.hdf5. Skipping it.
# File not found: lc/001026.hdf5. Skipping it.
# File not found: lc/001027.hdf5. Skipping it.
# File not found: lc/001028.hdf5. Skipping it.
# File not found: lc/001029.hdf5. Skipping it.
# File not found: lc/001030.hdf5. Skipping it.
# File not found: lc/001031.hdf5. Skipping it.
# File not found: lc/001032.hdf5. Skipping it.
# File not found: lc/001033.hdf5. Skipping it.
# File not found: lc/001034.hdf5. Skipping it.
# File not found: lc/001035.hdf5. Skipping it.
# File not found: lc/001036.hdf5. Skipping it.
# File not found: lc/001037.hdf5. Skipping it.
# File not found: lc/001038.hdf5. Skipping it.
# File not found: lc/001039.hdf5. Skipping it.
# File not found: lc/001040.hdf5. Skipping it.
# File not found: lc/001041.hdf5. Skipping it.
# File not found: lc/001042.hdf5. Skipping it.
# File not found: lc/001043.hdf5. Skipping it.
# File not found: lc/001044.hdf5. Skipping it.
# File not found: lc/001045.hdf5. Skipping it.
# File not found: lc/001046.hdf5. Skipping it.
# File not found: lc/001047.hdf5. Skipping it.
# File not found: lc/001048.hdf5. Skipping it.
# File not found: lc/001049.hdf5. Skipping it.
# File not found: lc/001050.hdf5. Skipping it.
# File not found: lc/001051.hdf5. Skipping it.
# File not found: lc/001052.hdf5. Skipping it.
# File not found: lc/001053.hdf5. Skipping it.
# File not found: lc/001054.hdf5. Skipping it.
# File not found: lc/001055.hdf5. Skipping it.
# File not found: lc/001056.hdf5. Skipping it.
# File not found: lc/001057.hdf5. Skipping it.
# File not found: lc/001058.hdf5. Skipping it.
# File not found: lc/001059.hdf5. Skipping it.
# File not found: lc/001060.hdf5. Skipping it.
# File not found: lc/001061.hdf5. Skipping it.
# File not found: lc/001062.hdf5. Skipping it.
# File not found: lc/001063.hdf5. Skipping it.
# File not found: lc/001064.hdf5. Skipping it.
# File not found: lc/001065.hdf5. Skipping it.
# File not found: lc/001066.hdf5. Skipping it.
# File not found: lc/001067.hdf5. Skipping it.
# File not found: lc/001068.hdf5. Skipping it.
# File not found: lc/001069.hdf5. Skipping it.
# File not found: lc/001070.hdf5. Skipping it.
# File not found: lc/001071.hdf5. Skipping it.
# File not found: lc/001072.hdf5. Skipping it.
# File not found: lc/001073.hdf5. Skipping it.
# File not found: lc/001074.hdf5. Skipping it.
# File not found: lc/001075.hdf5. Skipping it.
# File not found: lc/001076.hdf5. Skipping it.
# File not found: lc/001077.hdf5. Skipping it.
# File not found: lc/001078.hdf5. Skipping it.
# File not found: lc/001079.hdf5. Skipping it.
# File not found: lc/001080.hdf5. Skipping it.
# File not found: lc/001081.hdf5. Skipping it.
# File not found: lc/001082.hdf5. Skipping it.
# File not found: lc/001083.hdf5. Skipping it.
# File not found: lc/001084.hdf5. Skipping it.
# File not found: lc/001085.hdf5. Skipping it.
# File not found: lc/001086.hdf5. Skipping it.
# File not found: lc/001087.hdf5. Skipping it.
# File not found: lc/001088.hdf5. Skipping it.
# File not found: lc/001089.hdf5. Skipping it.
# File not found: lc/001090.hdf5. Skipping it.
# File not found: lc/001091.hdf5. Skipping it.
# File not found: lc/001092.hdf5. Skipping it.
# File not found: lc/001093.hdf5. Skipping it.
# File not found: lc/001094.hdf5. Skipping it.
# File not found: lc/001095.hdf5. Skipping it.
# File not found: lc/001096.hdf5. Skipping it.
# File not found: lc/001097.hdf5. Skipping it.
# File not found: lc/001098.hdf5. Skipping it.
# File not found: lc/001099.hdf5. Skipping it.
# File not found: lc/001100.hdf5. Skipping it.
# File not found: lc/001101.hdf5. Skipping it.
# File not found: lc/001102.hdf5. Skipping it.
# File not found: lc/001103.hdf5. Skipping it.
# File not found: lc/001104.hdf5. Skipping it.
# File not found: lc/001105.hdf5. Skipping it.
# File not found: lc/001106.hdf5. Skipping it.
# File not found: lc/001107.hdf5. Skipping it.
# File not found: lc/001108.hdf5. Skipping it.
# File not found: lc/001109.hdf5. Skipping it.
# File not found: lc/001110.hdf5. Skipping it.
# File not found: lc/001111.hdf5. Skipping it.
# File not found: lc/001112.hdf5. Skipping it.
# File not found: lc/001113.hdf5. Skipping it.
# File not found: lc/001114.hdf5. Skipping it.
# File not found: lc/001115.hdf5. Skipping it.
# File not found: lc/001116.hdf5. Skipping it.
# File not found: lc/001117.hdf5. Skipping it.
# File not found: lc/001118.hdf5. Skipping it.
# File not found: lc/001119.hdf5. Skipping it.
# File not found: lc/001120.hdf5. Skipping it.
# File not found: lc/001121.hdf5. Skipping it.
# File not found: lc/001122.hdf5. Skipping it.
# File not found: lc/001123.hdf5. Skipping it.
# File not found: lc/001124.hdf5. Skipping it.
# File not found: lc/001125.hdf5. Skipping it.
# File not found: lc/001126.hdf5. Skipping it.
# File not found: lc/001127.hdf5. Skipping it.
# File not found: lc/001128.hdf5. Skipping it.
# File not found: lc/001129.hdf5. Skipping it.
# File not found: lc/001130.hdf5. Skipping it.
# File not found: lc/001131.hdf5. Skipping it.
# File not found: lc/001132.hdf5. Skipping it.
# File not found: lc/001133.hdf5. Skipping it.
# File not found: lc/001134.hdf5. Skipping it.
# File not found: lc/001135.hdf5. Skipping it.
# File not found: lc/001136.hdf5. Skipping it.
# File not found: lc/001137.hdf5. Skipping it.
# File not found: lc/001138.hdf5. Skipping it.
# File not found: lc/001139.hdf5. Skipping it.
# File not found: lc/001140.hdf5. Skipping it.
# File not found: lc/001141.hdf5. Skipping it.
# File not found: lc/001142.hdf5. Skipping it.
# File not found: lc/001143.hdf5. Skipping it.
# File not found: lc/001144.hdf5. Skipping it.
# File not found: lc/001145.hdf5. Skipping it.
# File not found: lc/001146.hdf5. Skipping it.
# File not found: lc/001147.hdf5. Skipping it.
# File not found: lc/001148.hdf5. Skipping it.
# File not found: lc/001149.hdf5. Skipping it.
# File not found: lc/001150.hdf5. Skipping it.
# File not found: lc/001151.hdf5. Skipping it.
# File not found: lc/001152.hdf5. Skipping it.
# File not found: lc/001153.hdf5. Skipping it.
# File not found: lc/001154.hdf5. Skipping it.
# File not found: lc/001155.hdf5. Skipping it.
# File not found: lc/001156.hdf5. Skipping it.
# File not found: lc/001157.hdf5. Skipping it.
# File not found: lc/001158.hdf5. Skipping it.
# File not found: lc/001159.hdf5. Skipping it.
# File not found: lc/001160.hdf5. Skipping it.
# File not found: lc/001161.hdf5. Skipping it.
# File not found: lc/001162.hdf5. Skipping it.
# File not found: lc/001163.hdf5. Skipping it.
# File not found: lc/001164.hdf5. Skipping it.
# File not found: lc/001165.hdf5. Skipping it.
# File not found: lc/001166.hdf5. Skipping it.
# File not found: lc/001167.hdf5. Skipping it.
# File not found: lc/001168.hdf5. Skipping it.
# File not found: lc/001169.hdf5. Skipping it.
# File not found: lc/001170.hdf5. Skipping it.
# File not found: lc/001171.hdf5. Skipping it.
# File not found: lc/001172.hdf5. Skipping it.
# File not found: lc/001173.hdf5. Skipping it.
# File not found: lc/001174.hdf5. Skipping it.
# File not found: lc/001175.hdf5. Skipping it.
# File not found: lc/001176.hdf5. Skipping it.
# File not found: lc/001177.hdf5. Skipping it.
# File not found: lc/001178.hdf5. Skipping it.
# File not found: lc/001179.hdf5. Skipping it.
# File not found: lc/001180.hdf5. Skipping it.
# File not found: lc/001181.hdf5. Skipping it.
# File not found: lc/001182.hdf5. Skipping it.
# File not found: lc/001183.hdf5. Skipping it.
# File not found: lc/001184.hdf5. Skipping it.
# File not found: lc/001185.hdf5. Skipping it.
# File not found: lc/001186.hdf5. Skipping it.
# File not found: lc/001187.hdf5. Skipping it.
# File not found: lc/001188.hdf5. Skipping it.
# File not found: lc/001189.hdf5. Skipping it.
# File not found: lc/001190.hdf5. Skipping it.
# File not found: lc/001191.hdf5. Skipping it.
# File not found: lc/001192.hdf5. Skipping it.
# File not found: lc/001193.hdf5. Skipping it.
# File not found: lc/001194.hdf5. Skipping it.
# File not found: lc/001195.hdf5. Skipping it.
# File not found: lc/001196.hdf5. Skipping it.
# File not found: lc/001197.hdf5. Skipping it.
# File not found: lc/001198.hdf5. Skipping it.
# File not found: lc/001199.hdf5. Skipping it.
# File not found: lc/001200.hdf5. Skipping it.
# File not found: lc/001201.hdf5. Skipping it.
# File not found: lc/001202.hdf5. Skipping it.
# File not found: lc/001203.hdf5. Skipping it.
# File not found: lc/001204.hdf5. Skipping it.
# File not found: lc/001205.hdf5. Skipping it.
# File not found: lc/001206.hdf5. Skipping it.
# File not found: lc/001207.hdf5. Skipping it.
# File not found: lc/001208.hdf5. Skipping it.
# File not found: lc/001209.hdf5. Skipping it.
# File not found: lc/001210.hdf5. Skipping it.
# File not found: lc/001211.hdf5. Skipping it.
# File not found: lc/001212.hdf5. Skipping it.
# File not found: lc/001213.hdf5. Skipping it.
# File not found: lc/001214.hdf5. Skipping it.
# File not found: lc/001215.hdf5. Skipping it.
# File not found: lc/001216.hdf5. Skipping it.
# File not found: lc/001217.hdf5. Skipping it.
# File not found: lc/001218.hdf5. Skipping it.
# File not found: lc/001219.hdf5. Skipping it.
# File not found: lc/001220.hdf5. Skipping it.
# File not found: lc/001221.hdf5. Skipping it.
# File not found: lc/001222.hdf5. Skipping it.
# File not found: lc/001223.hdf5. Skipping it.
# File not found: lc/001224.hdf5. Skipping it.
# File not found: lc/001225.hdf5. Skipping it.
# File not found: lc/001226.hdf5. Skipping it.
# File not found: lc/001227.hdf5. Skipping it.
# File not found: lc/001228.hdf5. Skipping it.
# File not found: lc/001229.hdf5. Skipping it.
# File not found: lc/001230.hdf5. Skipping it.
# File not found: lc/001231.hdf5. Skipping it.
# File not found: lc/001232.hdf5. Skipping it.
# File not found: lc/001233.hdf5. Skipping it.
# File not found: lc/001234.hdf5. Skipping it.
# File not found: lc/001235.hdf5. Skipping it.
# File not found: lc/001236.hdf5. Skipping it.
# File not found: lc/001237.hdf5. Skipping it.
# File not found: lc/001238.hdf5. Skipping it.
# File not found: lc/001239.hdf5. Skipping it.
# File not found: lc/001240.hdf5. Skipping it.
# File not found: lc/001242.hdf5. Skipping it.
# File not found: lc/001250.hdf5. Skipping it.
# File not found: lc/001251.hdf5. Skipping it.
# File not found: lc/001252.hdf5. Skipping it.
# File not found: lc/001253.hdf5. Skipping it.
# File not found: lc/001254.hdf5. Skipping it.
# File not found: lc/001255.hdf5. Skipping it.
# File not found: lc/001256.hdf5. Skipping it.
# File not found: lc/001257.hdf5. Skipping it.
# File not found: lc/001258.hdf5. Skipping it.
# File not found: lc/001259.hdf5. Skipping it.
# File not found: lc/001260.hdf5. Skipping it.
# File not found: lc/001261.hdf5. Skipping it.
# File not found: lc/001262.hdf5. Skipping it.
# File not found: lc/001263.hdf5. Skipping it.
# File not found: lc/001264.hdf5. Skipping it.
# File not found: lc/001265.hdf5. Skipping it.
# File not found: lc/001266.hdf5. Skipping it.
# File not found: lc/001267.hdf5. Skipping it.
# File not found: lc/001268.hdf5. Skipping it.
# File not found: lc/001269.hdf5. Skipping it.
# File not found: lc/001270.hdf5. Skipping it.
# File not found: lc/001271.hdf5. Skipping it.
# File not found: lc/001272.hdf5. Skipping it.
# File not found: lc/001273.hdf5. Skipping it.
# File not found: lc/001274.hdf5. Skipping it.
# File not found: lc/001275.hdf5. Skipping it.
# File not found: lc/001276.hdf5. Skipping it.
# File not found: lc/001277.hdf5. Skipping it.
# File not found: lc/001278.hdf5. Skipping it.
# File not found: lc/001279.hdf5. Skipping it.
# File not found: lc/001280.hdf5. Skipping it.
# File not found: lc/001281.hdf5. Skipping it.
# File not found: lc/001282.hdf5. Skipping it.
# File not found: lc/001283.hdf5. Skipping it.
# File not found: lc/001284.hdf5. Skipping it.
# File not found: lc/001285.hdf5. Skipping it.
# File not found: lc/001286.hdf5. Skipping it.
#  60%|██████    | 913/1520 [34:37<00:07, 78.67it/s]
# File not found: lc/001303.hdf5. Skipping it.
# File not found: lc/001304.hdf5. Skipping it.
# File not found: lc/001305.hdf5. Skipping it.
# File not found: lc/001306.hdf5. Skipping it.
# File not found: lc/001307.hdf5. Skipping it.
# File not found: lc/001308.hdf5. Skipping it.
# File not found: lc/001309.hdf5. Skipping it.
# File not found: lc/001310.hdf5. Skipping it.
# File not found: lc/001311.hdf5. Skipping it.
# File not found: lc/001312.hdf5. Skipping it.
# File not found: lc/001313.hdf5. Skipping it.
# File not found: lc/001314.hdf5. Skipping it.
# File not found: lc/001315.hdf5. Skipping it.
# File not found: lc/001316.hdf5. Skipping it.
# File not found: lc/001317.hdf5. Skipping it.
# File not found: lc/001318.hdf5. Skipping it.
# File not found: lc/001319.hdf5. Skipping it.
# File not found: lc/001320.hdf5. Skipping it.
# File not found: lc/001321.hdf5. Skipping it.
# File not found: lc/001322.hdf5. Skipping it.
# File not found: lc/001323.hdf5. Skipping it.
# File not found: lc/001324.hdf5. Skipping it.
# File not found: lc/001325.hdf5. Skipping it.
# File not found: lc/001326.hdf5. Skipping it.
# File not found: lc/001327.hdf5. Skipping it.
# File not found: lc/001328.hdf5. Skipping it.
# File not found: lc/001329.hdf5. Skipping it.
# File not found: lc/001330.hdf5. Skipping it.
# File not found: lc/001331.hdf5. Skipping it.
# File not found: lc/001332.hdf5. Skipping it.
#  64%|██████▎   | 966/1520 [34:53<00:38, 14.27it/s]
# File not found: lc/001355.hdf5. Skipping it.
# File not found: lc/001357.hdf5. Skipping it.
# File not found: lc/001358.hdf5. Skipping it.
# File not found: lc/001359.hdf5. Skipping it.
# File not found: lc/001360.hdf5. Skipping it.
# File not found: lc/001361.hdf5. Skipping it.
# File not found: lc/001362.hdf5. Skipping it.
# File not found: lc/001363.hdf5. Skipping it.
# File not found: lc/001364.hdf5. Skipping it.
# File not found: lc/001365.hdf5. Skipping it.
# File not found: lc/001366.hdf5. Skipping it.
# File not found: lc/001367.hdf5. Skipping it.
# File not found: lc/001368.hdf5. Skipping it.
# File not found: lc/001369.hdf5. Skipping it.
# File not found: lc/001370.hdf5. Skipping it.
# File not found: lc/001371.hdf5. Skipping it.
# File not found: lc/001372.hdf5. Skipping it.
# File not found: lc/001373.hdf5. Skipping it.
# File not found: lc/001374.hdf5. Skipping it.
# File not found: lc/001375.hdf5. Skipping it.
# File not found: lc/001376.hdf5. Skipping it.
# File not found: lc/001378.hdf5. Skipping it.
# File not found: lc/001379.hdf5. Skipping it.
# File not found: lc/001380.hdf5. Skipping it.
# File not found: lc/001381.hdf5. Skipping it.
# File not found: lc/001382.hdf5. Skipping it.
#  69%|██████▊   | 1042/1520 [36:00<04:24,  1.81it/s]
# File not found: lc/001412.hdf5. Skipping it.
# File not found: lc/001413.hdf5. Skipping it.
# File not found: lc/001414.hdf5. Skipping it.
# File not found: lc/001415.hdf5. Skipping it.
# File not found: lc/001416.hdf5. Skipping it.
# File not found: lc/001417.hdf5. Skipping it.
# File not found: lc/001418.hdf5. Skipping it.
# File not found: lc/001419.hdf5. Skipping it.
# File not found: lc/001420.hdf5. Skipping it.
# File not found: lc/001421.hdf5. Skipping it.
# File not found: lc/001422.hdf5. Skipping it.
# File not found: lc/001423.hdf5. Skipping it.
# File not found: lc/001424.hdf5. Skipping it.
# File not found: lc/001432.hdf5. Skipping it.
#  72%|███████▏  | 1092/1520 [37:28<10:54,  1.53s/it]
# File not found: lc/001467.hdf5. Skipping it.
#  72%|███████▏  | 1093/1520 [37:30<11:14,  1.58s/it]
# File not found: lc/001470.hdf5. Skipping it.
#  72%|███████▏  | 1096/1520 [37:30<07:11,  1.02s/it]
# File not found: lc/001473.hdf5. Skipping it.
# File not found: lc/001474.hdf5. Skipping it.
# File not found: lc/001475.hdf5. Skipping it.
# 100%|██████████| 1520/1520 [49:48<00:00,  1.97s/it]
# File not found: lc/001888.hdf5. Skipping it.
# File not found: lc/001889.hdf5. Skipping it.
# File not found: lc/001890.hdf5. Skipping it.
# File not found: lc/001891.hdf5. Skipping it.
# File not found: lc/001894.hdf5. Skipping it.
# File not found: lc/001895.hdf5. Skipping it.

# %% [markdown]
# ## Convert magnitude to flux and calculate the weighted average flux and uncertainties and then do the reverse

# %%
def mag_flux(magnitude,uncertainties):
    f = 10 ** (-magnitude / 2.5)
    df = f * uncertainties * np.log(10) / (-2.5)
    return f,df

# %%
result1 = [mag_flux(mag_g[x],magerr_g[x]) for x in range(len(mag_g))]
result2 = [mag_flux(mag_r[x],magerr_r[x]) for x in range(len(mag_r))]
result3 = [mag_flux(mag_i[x],magerr_i[x]) for x in range(len(mag_i))]

f_g = [x[0] for x in result1]
df_g = [x[1] for x in result1]

f_r = [x[0] for x in result2]
df_r = [x[1] for x in result2]

f_i = [x[0] for x in result3]
df_i = [x[1] for x in result3]

def weighted_average(f, df):
    # Calculate the weights
    weights = 1.0 / (df ** 2)
    
    # Calculate the weighted average magnitude
    weighted_flux = np.sum(f * weights) / np.sum(weights)

    # Calculate the weighted uncertainties
    weighted_uncertainties = np.sqrt(1.0 / np.sum(weights))

    return weighted_flux, weighted_uncertainties

result1 = [weighted_average(f_g[x],df_g[x]) for x in range(len(f_g)) ]
result2 = [weighted_average(f_r[x],df_r[x]) for x in range(len(f_r)) ]
result3 = [weighted_average(f_i[x],df_i[x]) for x in range(len(f_i)) ]



#print(len(result))
weighted_ave_f_g = [x[0] for x in result1]
weighted_ave_df_g = [x[1] for x in result1]

weighted_ave_f_r = [x[0] for x in result2]
weighted_ave_df_r = [x[1] for x in result2]

weighted_ave_f_i = [x[0] for x in result3]
weighted_ave_df_i = [x[1] for x in result3]
#print(weighted_ave_mag_g)
f_g = np.array(weighted_ave_f_g)
df_g = np.array(weighted_ave_df_g)

f_r = np.array(weighted_ave_f_r)
df_r = np.array(weighted_ave_df_r)

f_i = np.array(weighted_ave_f_i)
df_i = np.array(weighted_ave_df_i)

mag_g = -2.5 * np.log10(f_g)
mag_r = -2.5 * np.log10(f_r)
mag_i = -2.5 * np.log10(f_i)
magerr_g = 2.5 / np.log(10) * df_g / f_g
magerr_r = 2.5 / np.log(10) * df_r / f_r
magerr_i = 2.5 / np.log(10) * df_i / f_i

# %%
target_id_g = np.array(target_id_g)
target_id_r = np.array(target_id_r)
target_id_i = np.array(target_id_i)

# %%
mjd_g = []
for target_id in target_id_g: 
    target_id = int(target_id)
    index = (targetid == target_id)
    mjd_g.append(mjd[index][0])
mjd_r = []
for target_id in target_id_r: 
    target_id = int(target_id)
    index = (targetid == target_id)
    mjd_r.append(mjd[index][0])
mjd_i = []
for target_id in target_id_i: 
    target_id = int(target_id)
    index = (targetid == target_id)
    mjd_i.append(mjd[index][0])

# %%
mjd_g = np.array(mjd_g)
mjd_r = np.array(mjd_r)
mjd_i = np.array(mjd_i)

# %%
# Create a dictionary with column names as keys and arrays as values
import pandas as pd
data = {
    'target_id_g': target_id_g,
    'mjd_g': mjd_g,
    'mag_g': mag_g,
    'magerr_g': magerr_g
}

# Convert the dictionary to a Pandas DataFrame
df = pd.DataFrame(data)

# Define the file path for the CSV file
csv_file_path = "g.csv"

# Save the Pandas DataFrame to a CSV file
df.to_csv(csv_file_path, index=False)

# %%
# Create a dictionary with column names as keys and arrays as values
import pandas as pd
data = {
    'target_id_r': target_id_r,
    'mjd_r': mjd_r,
    'mag_r': mag_r,
    'magerr_r': magerr_r
}

# Convert the dictionary to a Pandas DataFrame
df = pd.DataFrame(data)

# Define the file path for the CSV file
csv_file_path = "r.csv"

# Save the Pandas DataFrame to a CSV file
df.to_csv(csv_file_path, index=False)

# %%
# Create a dictionary with column names as keys and arrays as values
import pandas as pd
data = {
    'target_id_i': target_id_i,
    'mjd_i': mjd_i,
    'mag_i': mag_i,
    'magerr_i': magerr_i
}

# Convert the dictionary to a Pandas DataFrame
df = pd.DataFrame(data)

# Define the file path for the CSV file
csv_file_path = "i.csv"

# Save the Pandas DataFrame to a CSV file
df.to_csv(csv_file_path, index=False)

# %% [markdown]
# # Plot magnitude with uncertainty along the time baseline

# %%
sorted_indices = np.argsort(mjd_g)
sorted_mjd_g = mjd_g[sorted_indices]
sorted_mag_g = mag_g[sorted_indices]
sorted_magerr_g = magerr_g[sorted_indices]
plt.figure(figsize=(25, 25))
# Create the scatter plot with error bars
plt.subplot(221)
plt.errorbar(sorted_mjd_g, sorted_mag_g, yerr=np.abs(sorted_magerr_g), fmt='o', color='blue', capsize=5, markersize=0.01, label='Magnitude with Error')
# Customize plot labels and appearance
plt.xlabel('MJD')
plt.ylabel('Magnitude_g')
plt.title('Magnitude_g with uncertainty along the time baseline')
plt.legend()

# Show the plot
plt.grid(True)

sorted_indices = np.argsort(mjd_r)
sorted_mjd_r = mjd_r[sorted_indices]
sorted_mag_r = mag_r[sorted_indices]
sorted_magerr_r = magerr_r[sorted_indices]

# Create the scatter plot with error bars
plt.subplot(222)
plt.errorbar(sorted_mjd_r, sorted_mag_r, yerr=np.abs(sorted_magerr_r), fmt='o', color='blue', capsize=5, markersize=0.01, label='Magnitude with Error')
# Customize plot labels and appearance
plt.xlabel('MJD')
plt.ylabel('Magnitude_r')
plt.title('magnitude_r with uncertainty along the time baseline')
plt.legend()

# Show the plot
plt.grid(True)
sorted_indices = np.argsort(mjd_i)
sorted_mjd_i = mjd_i[sorted_indices]
sorted_mag_i = mag_i[sorted_indices]
sorted_magerr_i = magerr_i[sorted_indices]

# Create the scatter plot with error bars
plt.subplot(223)

plt.errorbar(sorted_mjd_i, sorted_mag_i, yerr=np.abs(sorted_magerr_i), fmt='o', color='blue', capsize=5, markersize=0.01, label='Magnitude with Error')
# Customize plot labels and appearance
plt.xlabel('MJD')
plt.ylabel('Magnitude_i')
plt.title('Magnitude_i with uncertainty along the time baseline')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %% [markdown]
# # Plot the distribution of magnitude and uncertainty

# %%
plt.figure(figsize=(25, 15))
plt.subplot(121)
# Create the histogram without filling the bars (histtype='step')
plt.hist(mag_g, bins=300, range=(18, 22), histtype='step', color='black', label='magnitude_g', alpha=1)
plt.hist(mag_r, bins=300, range=(18, 22), histtype='step', color='blue', label='magnitude_r', alpha=1)
plt.hist(mag_i, bins=300, range=(18, 22), histtype='step', color='red', label='magnitude_i', alpha=1)
# Customize plot labels and appearance
plt.xlabel('Magnitudes')
plt.ylabel('Number of Entries')
plt.title('Histogram of Magnitudes')
plt.legend()

# Show the plot
plt.grid(True)

plt.subplot(122)
# Create the histogram without filling the bars (histtype='step')
plt.hist(magerr_g, bins=300, range=(0, 0.3), histtype='step', color='black', label='uncertainties_g', alpha=1)
plt.hist(magerr_r, bins=300, range=(0, 0.3), histtype='step', color='blue', label='uncertainties_r', alpha=1)
plt.hist(magerr_i, bins=300, range=(0, 0.3), histtype='step', color='red', label='uncertainties_i', alpha=1)
# Customize plot labels and appearance
plt.xlabel('Uncertainties')
plt.ylabel('Number of Entries')
plt.title('Histogram of Uncertainties')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %% [markdown]
# # Plot the histogram of uncertainties for different time windows,set the mean of mjd as the DESI observation time

# %%
mjd_g_mean = np.mean(mjd_g)
mjd_r_mean = np.mean(mjd_r)
mjd_i_mean = np.mean(mjd_i)
def time_window_g(mjd,window,magerr):
    start = mjd_g_mean - window / 2
    end = mjd_g_mean + window / 2
    indices_g = (mjd >= start) & (mjd <= end)
    
    magerr_g_within_window = magerr[indices_g]
    
    return magerr_g_within_window
def time_window_r(mjd,window,magerr):
    start = mjd_r_mean - window / 2
    end = mjd_r_mean + window / 2
    indices_r = (mjd >= start) & (mjd <= end)
    
    magerr_r_within_window = magerr[indices_r]
    
    return magerr_r_within_window
def time_window_i(mjd,window,magerr):
    start = mjd_i_mean - window / 2
    end = mjd_i_mean + window / 2
    indices_i = (mjd >= start) & (mjd <= end)
    
    magerr_i_within_window = magerr[indices_i]
    
    return magerr_i_within_window

# %%
magerr_g_within_700 = time_window_g(mjd_g,700,magerr_g)
magerr_g_within_300 = time_window_g(mjd_g,300,magerr_g)
magerr_g_within_100 = time_window_g(mjd_g,100,magerr_g)
magerr_g_within_50 = time_window_g(mjd_g,50,magerr_g)

magerr_r_within_700 = time_window_r(mjd_r,700,magerr_r)
magerr_r_within_300 = time_window_r(mjd_r,300,magerr_r)
magerr_r_within_100 = time_window_r(mjd_r,100,magerr_r)
magerr_r_within_50 = time_window_r(mjd_r,50,magerr_r)

magerr_i_within_700 = time_window_i(mjd_i,700,magerr_i)
magerr_i_within_300 = time_window_i(mjd_i,300,magerr_i)
magerr_i_within_100 = time_window_i(mjd_i,100,magerr_i)
magerr_i_within_50 = time_window_i(mjd_i,50,magerr_i)

# %%
plt.figure(figsize=(25, 30))
plt.subplot(221)
# Create the histogram without filling the bars (histtype='step')
plt.hist(magerr_g_within_700, bins=100, range=(0, 0.3), histtype='step', color='black', label='300d', alpha=1,density=True)
plt.hist(magerr_g_within_300, bins=100, range=(0, 0.3), histtype='step', color='black', label='300d', alpha=1,density=True)
plt.hist(magerr_g_within_100, bins=100, range=(0, 0.3), histtype='step', color='blue', label='100d', alpha=1,density=True)
plt.hist(magerr_g_within_50, bins=100, range=(0, 0.3), histtype='step', color='red', label='10d', alpha=1,density=True)
# Customize plot labels and appearance
plt.xlabel('magerr_g')
plt.ylabel('Number of Entries')
plt.title('Histogram of Uncertainties for different time windows')
plt.legend()

# Show the plot
plt.grid(True)
plt.subplot(222)

# Create the histogram without filling the bars (histtype='step')
plt.hist(magerr_r_within_700, bins=100, range=(0, 0.3), histtype='step', color='black', label='300d', alpha=1,density=True)
plt.hist(magerr_r_within_300, bins=100, range=(0, 0.3), histtype='step', color='black', label='300d', alpha=1,density=True)
plt.hist(magerr_r_within_100, bins=100, range=(0, 0.3), histtype='step', color='blue', label='100d', alpha=1,density=True)
plt.hist(magerr_r_within_50, bins=100, range=(0, 0.3), histtype='step', color='red', label='10d', alpha=1,density=True)
# Customize plot labels and appearance
plt.xlabel('magerr_r')
plt.ylabel('Number of Entries')
plt.title('Histogram of Uncertainties for different time windows')
plt.legend()

# Show the plot
plt.grid(True)
plt.subplot(223)

# Create the histogram without filling the bars (histtype='step')
plt.hist(magerr_i_within_700, bins=100, range=(0, 0.3), histtype='step', color='black', label='300d', alpha=1,density=True)
plt.hist(magerr_i_within_300, bins=100, range=(0, 0.3), histtype='step', color='black', label='300d', alpha=1,density=True)
plt.hist(magerr_i_within_100, bins=100, range=(0, 0.3), histtype='step', color='blue', label='100d', alpha=1,density=True)
plt.hist(magerr_i_within_50, bins=100, range=(0, 0.3), histtype='step', color='red', label='10d', alpha=1,density=True)
# Customize plot labels and appearance
plt.xlabel('magerr_i')
plt.ylabel('Number of Entries')
plt.title('Histogram of Uncertainties for different time windows')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %% [markdown]
# # Plot histograms of redshift

# %% [markdown]
# ## Plot redshifts with uncertainty along the time baseline

# %%
sorted_indices = np.argsort(mjd_sld)
sorted_mjd_sld = mjd_sld[sorted_indices]
sorted_z = z_sld[sorted_indices]
sorted_zerr = zerr_sld[sorted_indices]
sorted_d = d[sorted_indices]

# Create the scatter plot with error bars
plt.figure(figsize=(25, 15))
plt.errorbar(sorted_mjd_sld, sorted_z, yerr=np.abs(sorted_zerr), fmt='o', color='blue', capsize=1, markersize=0.01, label='Magnitude with Error')
# Customize plot labels and appearance
plt.xlabel('MJD')
plt.ylabel('Redshifts')
plt.title('Redshifts with Error vs. MJD')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %% [markdown]
# ## Plot the distribution of redshifts, distance modulus and uncertainties

# %%
# Create the histogram without filling the bars (histtype='step')
plt.figure(figsize=(25, 15))

plt.hist(z_sld, bins=1000, range=(0, 5), histtype='step', color='black', label='redshifts', alpha=1)

# Customize plot labels and appearance
plt.xlabel('Redshift')
plt.ylabel('Number of Entries')
plt.title('Histogram of Redshifts')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %%
# Create the histogram without filling the bars (histtype='step')
plt.figure(figsize=(25, 15))

plt.hist(d, bins=1000, range=(30, 50), histtype='step', color='black', label='distance modulus', alpha=1)
# Customize plot labels and appearance
plt.xlabel('distance modulus')
plt.ylabel('Number of Entries')
plt.title('Histogram of distance modulus')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %%
# Create the histogram without filling the bars (histtype='step')
plt.figure(figsize=(25, 15))

plt.hist(zerr_sld, bins=1000, range=(0, 0.003), histtype='step', color='black', label='uncertainties', alpha=1)
# Customize plot labels and appearance
plt.xlabel('Redshift Uncertainties')
plt.ylabel('Number of Entries')
plt.title('Histogram of Redshifts Uncertainty')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %% [markdown]
# ## Plot the histograms of redshifts, distance modulus and uncertainties for different time windows, set the mean of mjd as the DESI observation time

# %%
mjd_mean = np.mean(mjd_sld)
def time_window(mjd, window,z,d,zerr):
    start = mjd - window / 2
    end = mjd + window / 2
    indices = (mjd_sld >= start) & (mjd_sld <= end)
    
    z_within_window = z[indices]
    d_within_window = d[indices]
    zerr_within_window = zerr[indices]
    
    return z_within_window, d_within_window, zerr_within_window
z_within_700,d_within_700,zerr_within_700 = time_window(mjd_mean,700,z_sld,d,zerr_sld)
z_within_300,d_within_300,zerr_within_300 = time_window(mjd_mean,300,z_sld,d,zerr_sld)
z_within_100,d_within_100,zerr_within_100 = time_window(mjd_mean,100,z_sld,d,zerr_sld)
z_within_10,d_within_10,zerr_within_10 = time_window(mjd_mean,10,z_sld,d,zerr_sld)

# %%
plt.figure(figsize=(25, 15))
# Create the histogram without filling the bars (histtype='step')
plt.hist(z_within_700, bins=100, range=(0, 5), histtype='step', color='black', label='700d', alpha=1,density=True)
plt.hist(z_within_300, bins=100, range=(0, 5), histtype='step', color='black', label='300d', alpha=1,density=True)
plt.hist(z_within_100, bins=100, range=(0, 5), histtype='step', color='blue', label='100d', alpha=1,density=True)
plt.hist(z_within_10, bins=100, range=(0, 5), histtype='step', color='red', label='10d', alpha=1,density=True)
# Customize plot labels and appearance
plt.xlabel('Redshift')
plt.ylabel('Number of Entries')
plt.title('Histogram of Redshifts')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %%
# Create the histogram without filling the bars (histtype='step')
plt.figure(figsize=(25, 15))

plt.hist(d_within_700, bins=100, range=(40, 50), histtype='step', color='black', label='700d', alpha=1,density=True)
plt.hist(d_within_300, bins=100, range=(40, 50), histtype='step', color='black', label='300d', alpha=1,density=True)
plt.hist(d_within_100, bins=100, range=(40, 50), histtype='step', color='blue', label='100d', alpha=1,density=True)
plt.hist(d_within_10, bins=100, range=(40, 50), histtype='step', color='red', label='10d', alpha=1,density=True)
# Customize plot labels and appearance
plt.xlabel('Distance modulus')
plt.ylabel('Number of Entries')
plt.title('Histogram of Distance modulus')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %%
# Create the histogram without filling the bars (histtype='step')
plt.figure(figsize=(25, 15))

plt.hist(zerr_within_700, bins=100, range=(0, 0.003), histtype='step', color='black', label='700d', alpha=1,density=True)
plt.hist(zerr_within_300, bins=100, range=(0, 0.003), histtype='step', color='black', label='300d', alpha=1,density=True)
plt.hist(zerr_within_100, bins=100, range=(0, 0.003), histtype='step', color='blue', label='100d', alpha=1,density=True)
plt.hist(zerr_within_10, bins=100, range=(0, 0.003), histtype='step', color='red', label='10d', alpha=1,density=True)
# Customize plot labels and appearance
plt.xlabel('Uncertainties')
plt.ylabel('Number of Entries')
plt.title('Histogram of Uncertainties')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %% [markdown]
# # Calculate absolute magnitudes of the quasars

# %%
def calculate_abs_mag(target_ids, mags, z_values, targetid_sld):
    abs_mag = []
    z = []
    for target_id in target_ids:
        target_id_0 = int(target_id)
        if target_id_0 in targetid_sld:
            indice_1 = (target_ids == target_id)
            indice_2 = (targetid_sld == target_id_0)
            wei_mag = mags[indice_1]
            mag = wei_mag - d.value[indice_2]
            abs_mag.append(mag)
            z.append(z_values[indice_2])
    return abs_mag, z

abs_mag_g, z_g = calculate_abs_mag(target_id_g, mag_g, z_sld, targetid_sld)
abs_mag_r, z_r = calculate_abs_mag(target_id_r, mag_r, z_sld, targetid_sld)
abs_mag_i, z_i = calculate_abs_mag(target_id_i, mag_i, z_sld, targetid_sld)

# %%
# Sample data (replace with your actual data)
plt.figure(figsize=(25, 15))

# Band g
plt.subplot(221)
plt.errorbar(z_g, abs_mag_g, yerr=magerr_g[0], fmt='o', color='b', ecolor='r', capsize=4)
plt.title('Redshift vs. Absolute Magnitude band g')
plt.xlabel('Redshift')
plt.ylabel('Absolute Magnitude')
plt.grid(True)
# Band r
plt.subplot(222)
plt.errorbar(z_r, abs_mag_r, yerr=magerr_r[0], fmt='o', color='b', ecolor='r', capsize=4)
plt.title('Redshift vs. Absolute Magnitude band r')
plt.xlabel('Redshift')
plt.ylabel('Absolute Magnitude')
plt.grid(True)
#Band i
plt.subplot(223)
plt.errorbar(z_i, abs_mag_i, yerr=magerr_i[0], fmt='o', color='b', ecolor='r', capsize=4)
plt.title('Redshift vs. Absolute Magnitude band i')
plt.xlabel('Redshift')
plt.ylabel('Absolute Magnitude')
plt.grid(True)
plt.show
